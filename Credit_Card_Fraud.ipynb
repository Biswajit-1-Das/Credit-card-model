# %% [markdown]
# <a href="https://colab.research.google.com/github/Biswajit-1-Das/Credit-card-model/blob/main/Credit_Card_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/CreditCard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32832 entries, 0 to 32831
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    32832 non-null  int64
#  1   V1      32832 non-null  float64
#  2   V2      32832 non-null  float64
#  3   V3      32832 non-null  float64
#  4   V4      32832 non-null  float64
#  5   V5      32832 non-null  float64
#  6   V6      32832 non-null  float64
#  7   V7      32832 non-null  float64
#  8   V8      32832 non-null  float64
#  9   V9      32832 non-null  float64
#  10  V10     32832 non-null  float64
#  11  V11     32832 non-null  float64
#  12  V12     32831 non-null  float64
#  13  V13     32831 non-null  float64
#  14  V14     32831 non-null  float64
#  15  V15     32831 non-null  float64
#  16  V16     32831 non-null  float64
#  17  V17     32831 non-null  float64
#  18  V18     32831 non-null  float64
#  19  V19     32831 non-null  float64
# ...

# %% [markdown]
# 0 ----> Legit Transaction
# 1 ----> Fraudulent Transaction

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    32729
# 1.0      102
# Name: count, dtype: int64

# %% [markdown]
# Data is highly unbalanced

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (32729, 31)
# (102, 31)

# %%
legit.Amount.describe()
# Out:
# count    32729.000000
# mean        82.155011
# std        225.057767
# min          0.000000
# 25%          6.980000
# 50%         20.610000
# 75%         74.900000
# max       7879.420000
# Name: Amount, dtype: float64

# %% [markdown]
# The values are in Percentile not in Percentage

# %%
fraud.Amount.describe()
# Out:
# count     102.000000
# mean       91.237451
# std       248.270971
# min         0.000000
# 25%         1.000000
# 50%         3.440000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    22798.385530 -0.189313  0.078561   0.755386  0.190391 -0.196998
# 1.0    20334.872549 -7.761095  5.946853 -11.035230  5.926171 -5.529543
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.097897 -0.095432  0.018209  0.309657  ...  0.042899 -0.034696
# 1.0   -2.295415 -7.767215  3.904551 -2.997290  ...  0.679987  0.641900
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.116341 -0.040218  0.009413  0.135065  0.021396  0.010290  0.003096
# 1.0   -0.352131 -0.317568 -0.241053  0.314412  0.177056  0.811372  0.118708
#
#           Amount
# Class
# 0.0    82.155011
# 1.0    91.237451
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_df=pd.concat([legit_sample,fraud],axis=0)

# %%
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8998   12473 -4.554169 -4.545418  0.530383 -0.703064  0.914786 -0.601146
# 24929  33445 -0.826414  0.498070  1.697485 -0.043207 -0.960275  0.083436
# 16626  27983 -0.099527  1.485823 -0.120791  0.588564  0.886781 -0.649394
# 14062  25030  1.067383 -0.714503  2.153129  0.955808 -1.760638  0.709885
# 16161  27581  0.930186 -0.971779  0.745749  0.329233 -0.532927  1.960257
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 8998  -0.574160  0.858082  2.812112  ...  0.561988 -0.184314  0.615255
# 24929  0.832737 -0.855693 -0.463092  ... -0.109516  0.715979 -0.072549
# 16626  1.231776 -0.460429 -0.070266  ... -0.021814  0.508076 -0.121641
# 14062 -1.584835  0.431401  3.508885  ... -0.073949  0.552715 -0.014311
# 16161 -1.150123  0.747305 -0.579613  ... -0.040428  0.434785  0.012604
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30398  35906 -3.519030  4.140867 -3.628202  5.505672 -4.057463 -0.905945
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 30398 -6.652031  2.634524 -4.679402  ...  1.582556  0.778710 -0.135707
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042  0.920021 -0.151104
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    102
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    22512.012195 -0.124665  0.114332   0.729533  0.088264 -0.141760
# 1.0    20334.872549 -7.761095  5.946853 -11.035230  5.926171 -5.529543
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.068757 -0.055310  0.031090  0.287178  ...  0.062018 -0.013356
# 1.0   -2.295415 -7.767215  3.904551 -2.997290  ...  0.679987  0.641900
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.112076 -0.029614 -0.012150  0.154867 -0.020658 -0.005248 -0.016850
# 1.0   -0.352131 -0.317568 -0.241053  0.314412  0.177056  0.811372  0.118708
#
#           Amount
# Class
# 0.0    68.925020
# 1.0    91.237451
#
# [2 rows x 30 columns]

# %%
X=new_df.drop(columns='Class',axis=1)
Y=new_df['Class']

# %%
print (X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8998   12473 -4.554169 -4.545418  0.530383 -0.703064  0.914786 -0.601146
# 24929  33445 -0.826414  0.498070  1.697485 -0.043207 -0.960275  0.083436
# 16626  27983 -0.099527  1.485823 -0.120791  0.588564  0.886781 -0.649394
# 14062  25030  1.067383 -0.714503  2.153129  0.955808 -1.760638  0.709885
# 16161  27581  0.930186 -0.971779  0.745749  0.329233 -0.532927  1.960257
# ...      ...       ...       ...       ...       ...       ...       ...
# 30398  35906 -3.519030  4.140867 -3.628202  5.505672 -4.057463 -0.905945
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print (Y)
# Out:
# 8998     0.0
# 24929    0.0
# 16626    0.0
# 14062    0.0
# 16161    0.0
#         ...
# 30398    1.0
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# Name: Class, Length: 594, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (594, 30) (475, 30) (119, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print ('Accuracy of training data : ' , training_data_accuracy)
# Out:
# Accuracy of training data :  0.9852631578947368

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print ('Accuracy of test data : ' , test_data_accuracy)
# Out:
# Accuracy of test data :  0.957983193277311
